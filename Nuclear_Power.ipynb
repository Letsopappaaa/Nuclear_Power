# %% [markdown]
# # Nuclear power around the world
#
# ### It is challanging to find a comprihensive dataset of power production on a reactor level. The most detailed public data out there is available on pris.iaea.org, however there is no way to download this data, so it has to be scraped.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import time
import numpy as np

# %%
baseURL = 'https://pris.iaea.org/PRIS/CountryStatistics/ReactorDetails.aspx?current='

headers = {
    'User-Agent': 'Personal project; Peter Oravecz',
    'From': 'peteroravecz94@gmail.com'
}

main_tables_list = []
reactor_details_list = []

#The URL of reactor details simply ends in the index number of the reactor.
for i in range(1,1150):
	cur_url = baseURL + str(i)
	cur_html = requests.get(cur_url, headers = headers).text
	soup = BeautifulSoup(cur_html, 'html.parser')
	#Some reactor index numbers are not populated, those URLs return an error page
	if soup.find('div', id='content').h3.text.strip() != "Unauthorized Access" and soup.find('div', id='content').h3.text.strip() != "Unexpected Problem Occurred":
		##Parsing HTML to find country and reactor name, html tables
		tables = pd.read_html(cur_html)
		reactor_name = soup.find('span', id='MainContent_MainContent_lblReactorName').b.text.strip()
		country_name = soup.find('a', id='MainContent_litCaption').text.strip().capitalize()
        
        #Replacing some country names to have no commas. Tableau gets confused from commas within strings in CSV files, at least I was not able to figure out a way to make it work properly.
		if country_name == "Iran, islamic republic of":
			country_name = "Iran"
		elif country_name == "Korea, republic of":
			country_name = "Korea"
		elif country_name == "Taiwan, china":
			country_name = "Taiwan"

		#Some reactors do not have any production data, and no main data table which means there are only 2 tables on the page
		if len(tables)>2:
			##Amending main data table with country and reactor names
			tables[2]["Country"] = country_name
			tables[2]["Reactor_name"] = reactor_name
			#Add main table data to list
			main_tables_list = main_tables_list + tables[2].values.tolist()

		#Add reactor details to list
		current_detail = [tables[0][0][1],
                          tables[0][1][1],
                          tables[0][1][3],
                          tables[0][0][5],
                          tables[0][1][7],
                          tables[0][2][1],
                          tables[0][3][1],
                          tables[0][0][9],
                          country_name,
                          reactor_name]
		reactor_details_list.append(current_detail)
		message = "Reactor ID: (" + str(i) + ") details collected."
	else:
		message = "Reactor ID: (" + str(i) + ") did not return a valid page."
	print(message)
	time.sleep(0.3)
# Out:
# Reactor ID: (1) details collected.
# Reactor ID: (2) details collected.
# Reactor ID: (3) details collected.
# Reactor ID: (4) details collected.
# Reactor ID: (5) details collected.
# Reactor ID: (6) did not return a valid page.
# Reactor ID: (7) did not return a valid page.
# Reactor ID: (8) details collected.
# Reactor ID: (9) details collected.
# Reactor ID: (10) details collected.
# Reactor ID: (11) details collected.
# Reactor ID: (12) details collected.
# Reactor ID: (13) details collected.
# Reactor ID: (14) details collected.
# Reactor ID: (15) details collected.
# Reactor ID: (16) details collected.
# Reactor ID: (17) details collected.
# Reactor ID: (18) details collected.
# Reactor ID: (19) details collected.
# Reactor ID: (20) details collected.
# Reactor ID: (21) details collected.
# Reactor ID: (22) did not return a valid page.
# Reactor ID: (23) did not return a valid page.
# Reactor ID: (24) details collected.
# Reactor ID: (25) details collected.
# Reactor ID: (26) details collected.
# Reactor ID: (27) did not return a valid page.
# Reactor ID: (28) did not return a valid page.
# Reactor ID: (29) details collected.
# Reactor ID: (30) details collected.
# Reactor ID: (31) details collected.
# Reactor ID: (32) details collected.
# Reactor ID: (33) details collected.
# Reactor ID: (34) details collected.
# Reactor ID: (35) details collected.
# Reactor ID: (36) details collected.
# Reactor ID: (37) details collected.
# Reactor ID: (38) details collected.
# Reactor ID: (39) details collected.
# Reactor ID: (40) details collected.
# Reactor ID: (41) details collected.
# Reactor ID: (42) details collected.
# Reactor ID: (43) details collected.
# Reactor ID: (44) details collected.
# Reactor ID: (45) details collected.
# Reactor ID: (46) details collected.
# Reactor ID: (47) details collected.
# Reactor ID: (48) did not return a valid page.
# Reactor ID: (49) details collected.
# Reactor ID: (50) details collected.
# Reactor ID: (51) details collected.
# Reactor ID: (52) details collected.
# Reactor ID: (53) details collected.
# Reactor ID: (54) details collected.
# Reactor ID: (55) details collected.
# Reactor ID: (56) details collected.
# Reactor ID: (57) details collected.
# Reactor ID: (58) details collected.
# Reactor ID: (59) details collected.
# Reactor ID: (60) did not return a valid page.
# Reactor ID: (61) did not return a valid page.
# Reactor ID: (62) details collected.
# Reactor ID: (63) details collected.
# Reactor ID: (64) details collected.
# Reactor ID: (65) details collected.
# Reactor ID: (66) details collected.
# Reactor ID: (67) details collected.
# Reactor ID: (68) details collected.
# Reactor ID: (69) details collected.
# Reactor ID: (70) did not return a valid page.
# Reactor ID: (71) did not return a valid page.
# Reactor ID: (72) did not return a valid page.
# Reactor ID: (73) did not return a valid page.
# Reactor ID: (74) details collected.
# Reactor ID: (75) details collected.
# Reactor ID: (76) did not return a valid page.
# Reactor ID: (77) did not return a valid page.
# Reactor ID: (78) details collected.
# Reactor ID: (79) details collected.
# Reactor ID: (80) details collected.
# Reactor ID: (81) details collected.
# Reactor ID: (82) details collected.
# Reactor ID: (83) details collected.
# Reactor ID: (84) details collected.
# Reactor ID: (85) details collected.
# Reactor ID: (86) details collected.
# Reactor ID: (87) details collected.
# Reactor ID: (88) details collected.
# Reactor ID: (89) details collected.
# Reactor ID: (90) details collected.
# Reactor ID: (91) details collected.
# Reactor ID: (92) details collected.
# Reactor ID: (93) details collected.
# Reactor ID: (94) details collected.
# Reactor ID: (95) did not return a valid page.
# Reactor ID: (96) details collected.
# Reactor ID: (97) details collected.
# Reactor ID: (98) details collected.
# Reactor ID: (99) did not return a valid page.
# Reactor ID: (100) details collected.
# Reactor ID: (101) details collected.
# Reactor ID: (102) details collected.
# Reactor ID: (103) did not return a valid page.
# Reactor ID: (104) details collected.
# Reactor ID: (105) did not return a valid page.
# Reactor ID: (106) details collected.
# Reactor ID: (107) details collected.
# Reactor ID: (108) details collected.
# Reactor ID: (109) did not return a valid page.
# Reactor ID: (110) did not return a valid page.
# Reactor ID: (111) did not return a valid page.
# Reactor ID: (112) did not return a valid page.
# Reactor ID: (113) did not return a valid page.
# Reactor ID: (114) details collected.
# Reactor ID: (115) did not return a valid page.
# Reactor ID: (116) did not return a valid page.
# Reactor ID: (117) did not return a valid page.
# Reactor ID: (118) did not return a valid page.
# Reactor ID: (119) details collected.
# Reactor ID: (120) did not return a valid page.
# Reactor ID: (121) details collected.
# Reactor ID: (122) details collected.
# Reactor ID: (123) details collected.
# Reactor ID: (124) details collected.
# Reactor ID: (125) details collected.
# Reactor ID: (126) details collected.
# Reactor ID: (127) details collected.
# Reactor ID: (128) did not return a valid page.
# Reactor ID: (129) did not return a valid page.
# Reactor ID: (130) did not return a valid page.
# Reactor ID: (131) did not return a valid page.
# Reactor ID: (132) did not return a valid page.
# Reactor ID: (133) details collected.
# Reactor ID: (134) details collected.
# Reactor ID: (135) details collected.
# Reactor ID: (136) details collected.
# Reactor ID: (137) did not return a valid page.
# Reactor ID: (138) did not return a valid page.
# Reactor ID: (139) details collected.
# Reactor ID: (140) details collected.
# Reactor ID: (141) details collected.
# Reactor ID: (142) did not return a valid page.
# Reactor ID: (143) did not return a valid page.
# Reactor ID: (144) did not return a valid page.
# Reactor ID: (145) did not return a valid page.
# Reactor ID: (146) details collected.
# Reactor ID: (147) did not return a valid page.
# Reactor ID: (148) did not return a valid page.
# Reactor ID: (149) details collected.
# Reactor ID: (150) details collected.
# Reactor ID: (151) did not return a valid page.
# Reactor ID: (152) did not return a valid page.
# Reactor ID: (153) details collected.
# Reactor ID: (154) details collected.
# Reactor ID: (155) details collected.
# Reactor ID: (156) details collected.
# Reactor ID: (157) details collected.
# Reactor ID: (158) details collected.
# Reactor ID: (159) details collected.
# Reactor ID: (160) details collected.
# Reactor ID: (161) details collected.
# Reactor ID: (162) details collected.
# Reactor ID: (163) details collected.
# Reactor ID: (164) details collected.
# Reactor ID: (165) details collected.
# Reactor ID: (166) details collected.
# Reactor ID: (167) details collected.
# Reactor ID: (168) details collected.
# Reactor ID: (169) details collected.
# Reactor ID: (170) details collected.
# Reactor ID: (171) details collected.
# Reactor ID: (172) details collected.
# Reactor ID: (173) details collected.
# Reactor ID: (174) details collected.
# Reactor ID: (175) details collected.
# Reactor ID: (176) details collected.
# Reactor ID: (177) details collected.
# Reactor ID: (178) details collected.
# Reactor ID: (179) details collected.
# Reactor ID: (180) details collected.
# Reactor ID: (181) details collected.
# Reactor ID: (182) details collected.
# Reactor ID: (183) details collected.
# Reactor ID: (184) details collected.
# Reactor ID: (185) details collected.
# Reactor ID: (186) details collected.
# Reactor ID: (187) details collected.
# Reactor ID: (188) details collected.
# Reactor ID: (189) details collected.
# Reactor ID: (190) details collected.
# Reactor ID: (191) details collected.
# Reactor ID: (192) details collected.
# Reactor ID: (193) details collected.
# Reactor ID: (194) details collected.
# Reactor ID: (195) details collected.
# Reactor ID: (196) details collected.
# Reactor ID: (197) details collected.
# Reactor ID: (198) details collected.
# Reactor ID: (199) details collected.
# Reactor ID: (200) details collected.
# Reactor ID: (201) details collected.
# Reactor ID: (202) details collected.
# Reactor ID: (203) details collected.
# Reactor ID: (204) details collected.
# Reactor ID: (205) details collected.
# Reactor ID: (206) details collected.
# Reactor ID: (207) details collected.
# Reactor ID: (208) details collected.
# Reactor ID: (209) details collected.
# Reactor ID: (210) details collected.
# Reactor ID: (211) details collected.
# Reactor ID: (212) details collected.
# Reactor ID: (213) details collected.
# Reactor ID: (214) details collected.
# Reactor ID: (215) details collected.
# Reactor ID: (216) details collected.
# Reactor ID: (217) details collected.
# Reactor ID: (218) details collected.
# Reactor ID: (219) details collected.
# Reactor ID: (220) details collected.
# Reactor ID: (221) details collected.
# Reactor ID: (222) details collected.
# Reactor ID: (223) details collected.
# Reactor ID: (224) details collected.
# Reactor ID: (225) details collected.
# Reactor ID: (226) details collected.
# Reactor ID: (227) details collected.
# Reactor ID: (228) details collected.
# Reactor ID: (229) details collected.
# Reactor ID: (230) details collected.
# Reactor ID: (231) details collected.
# Reactor ID: (232) details collected.
# Reactor ID: (233) details collected.
# Reactor ID: (234) details collected.
# Reactor ID: (235) details collected.
# Reactor ID: (236) details collected.
# Reactor ID: (237) details collected.
# Reactor ID: (238) details collected.
# Reactor ID: (239) details collected.
# Reactor ID: (240) details collected.
# Reactor ID: (241) details collected.
# Reactor ID: (242) details collected.
# Reactor ID: (243) details collected.
# Reactor ID: (244) details collected.
# Reactor ID: (245) details collected.
# Reactor ID: (246) details collected.
# Reactor ID: (247) details collected.
# Reactor ID: (248) details collected.
# Reactor ID: (249) details collected.
# Reactor ID: (250) details collected.
# Reactor ID: (251) details collected.
# Reactor ID: (252) details collected.
# Reactor ID: (253) details collected.
# Reactor ID: (254) details collected.
# Reactor ID: (255) details collected.
# Reactor ID: (256) details collected.
# Reactor ID: (257) details collected.
# Reactor ID: (258) did not return a valid page.
# Reactor ID: (259) details collected.
# Reactor ID: (260) details collected.
# Reactor ID: (261) details collected.
# Reactor ID: (262) details collected.
# Reactor ID: (263) details collected.
# Reactor ID: (264) details collected.
# Reactor ID: (265) details collected.
# Reactor ID: (266) details collected.
# Reactor ID: (267) details collected.
# Reactor ID: (268) details collected.
# Reactor ID: (269) details collected.
# Reactor ID: (270) details collected.
# Reactor ID: (271) details collected.
# Reactor ID: (272) details collected.
# Reactor ID: (273) details collected.
# Reactor ID: (274) details collected.
# Reactor ID: (275) details collected.
# Reactor ID: (276) details collected.
# Reactor ID: (277) did not return a valid page.
# Reactor ID: (278) details collected.
# Reactor ID: (279) details collected.
# Reactor ID: (280) details collected.
# Reactor ID: (281) details collected.
# Reactor ID: (282) did not return a valid page.
# Reactor ID: (283) did not return a valid page.
# Reactor ID: (284) did not return a valid page.
# Reactor ID: (285) details collected.
# Reactor ID: (286) details collected.
# Reactor ID: (287) details collected.
# Reactor ID: (288) details collected.
# Reactor ID: (289) details collected.
# Reactor ID: (290) details collected.
# Reactor ID: (291) details collected.
# Reactor ID: (292) details collected.
# Reactor ID: (293) did not return a valid page.
# Reactor ID: (294) did not return a valid page.
# Reactor ID: (295) details collected.
# Reactor ID: (296) details collected.
# Reactor ID: (297) details collected.
# Reactor ID: (298) details collected.
# Reactor ID: (299) details collected.
# Reactor ID: (300) details collected.
# Reactor ID: (301) details collected.
# Reactor ID: (302) details collected.
# Reactor ID: (303) details collected.
# Reactor ID: (304) details collected.
# Reactor ID: (305) details collected.
# Reactor ID: (306) details collected.
# Reactor ID: (307) details collected.
# Reactor ID: (308) details collected.
# Reactor ID: (309) did not return a valid page.
# Reactor ID: (310) details collected.
# Reactor ID: (311) details collected.
# Reactor ID: (312) did not return a valid page.
# Reactor ID: (313) did not return a valid page.
# Reactor ID: (314) did not return a valid page.
# Reactor ID: (315) did not return a valid page.
# Reactor ID: (316) did not return a valid page.
# Reactor ID: (317) did not return a valid page.
# Reactor ID: (318) details collected.
# Reactor ID: (319) did not return a valid page.
# Reactor ID: (320) did not return a valid page.
# Reactor ID: (321) did not return a valid page.
# Reactor ID: (322) did not return a valid page.
# Reactor ID: (323) did not return a valid page.
# Reactor ID: (324) did not return a valid page.
# Reactor ID: (325) details collected.
# Reactor ID: (326) details collected.
# Reactor ID: (327) details collected.
# Reactor ID: (328) did not return a valid page.
# Reactor ID: (329) did not return a valid page.
# Reactor ID: (330) did not return a valid page.
# Reactor ID: (331) did not return a valid page.
# Reactor ID: (332) did not return a valid page.
# Reactor ID: (333) details collected.
# Reactor ID: (334) details collected.
# Reactor ID: (335) details collected.
# Reactor ID: (336) details collected.
# Reactor ID: (337) details collected.
# Reactor ID: (338) details collected.
# Reactor ID: (339) details collected.
# Reactor ID: (340) details collected.
# Reactor ID: (341) details collected.
# Reactor ID: (342) details collected.
# Reactor ID: (343) details collected.
# Reactor ID: (344) details collected.
# Reactor ID: (345) details collected.
# Reactor ID: (346) details collected.
# Reactor ID: (347) details collected.
# Reactor ID: (348) details collected.
# Reactor ID: (349) details collected.
# Reactor ID: (350) details collected.
# Reactor ID: (351) details collected.
# Reactor ID: (352) details collected.
# Reactor ID: (353) details collected.
# Reactor ID: (354) details collected.
# Reactor ID: (355) details collected.
# Reactor ID: (356) details collected.
# Reactor ID: (357) details collected.
# Reactor ID: (358) details collected.
# Reactor ID: (359) details collected.
# Reactor ID: (360) details collected.
# Reactor ID: (361) details collected.
# Reactor ID: (362) details collected.
# Reactor ID: (363) details collected.
# Reactor ID: (364) details collected.
# Reactor ID: (365) details collected.
# Reactor ID: (366) details collected.
# Reactor ID: (367) details collected.
# Reactor ID: (368) details collected.
# Reactor ID: (369) did not return a valid page.
# Reactor ID: (370) details collected.
# Reactor ID: (371) details collected.
# Reactor ID: (372) details collected.
# Reactor ID: (373) details collected.
# Reactor ID: (374) details collected.
# Reactor ID: (375) details collected.
# Reactor ID: (376) details collected.
# Reactor ID: (377) details collected.
# Reactor ID: (378) details collected.
# Reactor ID: (379) details collected.
# Reactor ID: (380) details collected.
# Reactor ID: (381) details collected.
# Reactor ID: (382) details collected.
# Reactor ID: (383) details collected.
# Reactor ID: (384) details collected.
# Reactor ID: (385) details collected.
# Reactor ID: (386) details collected.
# Reactor ID: (387) details collected.
# Reactor ID: (388) details collected.
# Reactor ID: (389) details collected.
# Reactor ID: (390) did not return a valid page.
# Reactor ID: (391) did not return a valid page.
# Reactor ID: (392) did not return a valid page.
# Reactor ID: (393) did not return a valid page.
# Reactor ID: (394) details collected.
# Reactor ID: (395) details collected.
# Reactor ID: (396) details collected.
# Reactor ID: (397) details collected.
# Reactor ID: (398) details collected.
# Reactor ID: (399) details collected.
# Reactor ID: (400) details collected.
# Reactor ID: (401) details collected.
# Reactor ID: (402) details collected.
# Reactor ID: (403) details collected.
# Reactor ID: (404) details collected.
# Reactor ID: (405) details collected.
# Reactor ID: (406) details collected.
# Reactor ID: (407) details collected.
# Reactor ID: (408) details collected.
# Reactor ID: (409) details collected.
# Reactor ID: (410) details collected.
# Reactor ID: (411) details collected.
# Reactor ID: (412) details collected.
# Reactor ID: (413) details collected.
# Reactor ID: (414) details collected.
# Reactor ID: (415) details collected.
# Reactor ID: (416) details collected.
# Reactor ID: (417) did not return a valid page.
# Reactor ID: (418) did not return a valid page.
# Reactor ID: (419) did not return a valid page.
# Reactor ID: (420) details collected.
# Reactor ID: (421) details collected.
# Reactor ID: (422) details collected.
# Reactor ID: (423) details collected.
# Reactor ID: (424) did not return a valid page.
# Reactor ID: (425) did not return a valid page.
# Reactor ID: (426) did not return a valid page.
# Reactor ID: (427) details collected.
# Reactor ID: (428) details collected.
# Reactor ID: (429) details collected.
# Reactor ID: (430) did not return a valid page.
# Reactor ID: (431) did not return a valid page.
# Reactor ID: (432) did not return a valid page.
# Reactor ID: (433) did not return a valid page.
# Reactor ID: (434) did not return a valid page.
# Reactor ID: (435) did not return a valid page.
# Reactor ID: (436) did not return a valid page.
# Reactor ID: (437) did not return a valid page.
# Reactor ID: (438) did not return a valid page.
# Reactor ID: (439) did not return a valid page.
# Reactor ID: (440) did not return a valid page.
# Reactor ID: (441) did not return a valid page.
# Reactor ID: (442) details collected.
# Reactor ID: (443) details collected.
# Reactor ID: (444) did not return a valid page.
# Reactor ID: (445) did not return a valid page.
# Reactor ID: (446) did not return a valid page.
# Reactor ID: (447) details collected.
# Reactor ID: (448) details collected.
# Reactor ID: (449) did not return a valid page.
# Reactor ID: (450) did not return a valid page.
# Reactor ID: (451) details collected.
# Reactor ID: (452) did not return a valid page.
# Reactor ID: (453) details collected.
# Reactor ID: (454) did not return a valid page.
# Reactor ID: (455) did not return a valid page.
# Reactor ID: (456) did not return a valid page.
# Reactor ID: (457) did not return a valid page.
# Reactor ID: (458) did not return a valid page.
# Reactor ID: (459) did not return a valid page.
# Reactor ID: (460) details collected.
# Reactor ID: (461) did not return a valid page.
# Reactor ID: (462) did not return a valid page.
# Reactor ID: (463) did not return a valid page.
# Reactor ID: (464) did not return a valid page.
# Reactor ID: (465) did not return a valid page.
# Reactor ID: (466) did not return a valid page.
# Reactor ID: (467) details collected.
# Reactor ID: (468) details collected.
# Reactor ID: (469) details collected.
# Reactor ID: (470) details collected.
# Reactor ID: (471) did not return a valid page.
# Reactor ID: (472) did not return a valid page.
# Reactor ID: (473) did not return a valid page.
# Reactor ID: (474) details collected.
# Reactor ID: (475) details collected.
# Reactor ID: (476) details collected.
# Reactor ID: (477) did not return a valid page.
# Reactor ID: (478) did not return a valid page.
# Reactor ID: (479) did not return a valid page.
# Reactor ID: (480) did not return a valid page.
# Reactor ID: (481) did not return a valid page.
# Reactor ID: (482) did not return a valid page.
# Reactor ID: (483) details collected.
# Reactor ID: (484) details collected.
# Reactor ID: (485) details collected.
# Reactor ID: (486) details collected.
# Reactor ID: (487) details collected.
# Reactor ID: (488) details collected.
# Reactor ID: (489) details collected.
# Reactor ID: (490) details collected.
# Reactor ID: (491) details collected.
# Reactor ID: (492) details collected.
# Reactor ID: (493) details collected.
# Reactor ID: (494) details collected.
# Reactor ID: (495) details collected.
# Reactor ID: (496) details collected.
# Reactor ID: (497) details collected.
# Reactor ID: (498) details collected.
# Reactor ID: (499) details collected.
# Reactor ID: (500) did not return a valid page.
# Reactor ID: (501) did not return a valid page.
# Reactor ID: (502) details collected.
# Reactor ID: (503) details collected.
# Reactor ID: (504) did not return a valid page.
# Reactor ID: (505) details collected.
# Reactor ID: (506) details collected.
# Reactor ID: (507) details collected.
# Reactor ID: (508) details collected.
# Reactor ID: (509) did not return a valid page.
# Reactor ID: (510) did not return a valid page.
# Reactor ID: (511) did not return a valid page.
# Reactor ID: (512) did not return a valid page.
# Reactor ID: (513) details collected.
# Reactor ID: (514) did not return a valid page.
# Reactor ID: (515) did not return a valid page.
# Reactor ID: (516) did not return a valid page.
# Reactor ID: (517) did not return a valid page.
# Reactor ID: (518) did not return a valid page.
# Reactor ID: (519) details collected.
# Reactor ID: (520) did not return a valid page.
# Reactor ID: (521) did not return a valid page.
# Reactor ID: (522) did not return a valid page.
# Reactor ID: (523) did not return a valid page.
# Reactor ID: (524) details collected.
# Reactor ID: (525) details collected.
# Reactor ID: (526) details collected.
# Reactor ID: (527) details collected.
# Reactor ID: (528) details collected.
# Reactor ID: (529) details collected.
# Reactor ID: (530) details collected.
# Reactor ID: (531) details collected.
# Reactor ID: (532) details collected.
# Reactor ID: (533) did not return a valid page.
# Reactor ID: (534) details collected.
# Reactor ID: (535) details collected.
# Reactor ID: (536) details collected.
# Reactor ID: (537) details collected.
# Reactor ID: (538) details collected.
# Reactor ID: (539) details collected.
# Reactor ID: (540) details collected.
# Reactor ID: (541) details collected.
# Reactor ID: (542) details collected.
# Reactor ID: (543) details collected.
# Reactor ID: (544) details collected.
# Reactor ID: (545) details collected.
# Reactor ID: (546) details collected.
# Reactor ID: (547) details collected.
# Reactor ID: (548) details collected.
# Reactor ID: (549) details collected.
# Reactor ID: (550) details collected.
# Reactor ID: (551) details collected.
# Reactor ID: (552) did not return a valid page.
# Reactor ID: (553) details collected.
# Reactor ID: (554) details collected.
# Reactor ID: (555) details collected.
# Reactor ID: (556) details collected.
# Reactor ID: (557) details collected.
# Reactor ID: (558) details collected.
# Reactor ID: (559) details collected.
# Reactor ID: (560) did not return a valid page.
# Reactor ID: (561) did not return a valid page.
# Reactor ID: (562) did not return a valid page.
# Reactor ID: (563) did not return a valid page.
# Reactor ID: (564) did not return a valid page.
# Reactor ID: (565) did not return a valid page.
# Reactor ID: (566) details collected.
# Reactor ID: (567) details collected.
# Reactor ID: (568) details collected.
# Reactor ID: (569) details collected.
# Reactor ID: (570) details collected.
# Reactor ID: (571) details collected.
# Reactor ID: (572) details collected.
# Reactor ID: (573) details collected.
# Reactor ID: (574) details collected.
# Reactor ID: (575) details collected.
# Reactor ID: (576) details collected.
# Reactor ID: (577) details collected.
# Reactor ID: (578) details collected.
# Reactor ID: (579) details collected.
# Reactor ID: (580) did not return a valid page.
# Reactor ID: (581) details collected.
# Reactor ID: (582) details collected.
# Reactor ID: (583) did not return a valid page.
# Reactor ID: (584) details collected.
# Reactor ID: (585) did not return a valid page.
# Reactor ID: (586) details collected.
# Reactor ID: (587) did not return a valid page.
# Reactor ID: (588) did not return a valid page.
# Reactor ID: (589) details collected.
# Reactor ID: (590) did not return a valid page.
# Reactor ID: (591) did not return a valid page.
# Reactor ID: (592) did not return a valid page.
# Reactor ID: (593) did not return a valid page.
# Reactor ID: (594) details collected.
# Reactor ID: (595) details collected.
# Reactor ID: (596) details collected.
# Reactor ID: (597) details collected.
# Reactor ID: (598) details collected.
# Reactor ID: (599) details collected.
# Reactor ID: (600) details collected.
# Reactor ID: (601) details collected.
# Reactor ID: (602) details collected.
# Reactor ID: (603) details collected.
# Reactor ID: (604) details collected.
# Reactor ID: (605) details collected.
# Reactor ID: (606) details collected.
# Reactor ID: (607) details collected.
# Reactor ID: (608) details collected.
# Reactor ID: (609) details collected.
# Reactor ID: (610) details collected.
# Reactor ID: (611) details collected.
# Reactor ID: (612) details collected.
# Reactor ID: (613) details collected.
# Reactor ID: (614) details collected.
# Reactor ID: (615) details collected.
# Reactor ID: (616) details collected.
# Reactor ID: (617) details collected.
# Reactor ID: (618) details collected.
# Reactor ID: (619) details collected.
# Reactor ID: (620) details collected.
# Reactor ID: (621) details collected.
# Reactor ID: (622) details collected.
# Reactor ID: (623) details collected.
# Reactor ID: (624) details collected.
# Reactor ID: (625) details collected.
# Reactor ID: (626) details collected.
# Reactor ID: (627) details collected.
# Reactor ID: (628) details collected.
# Reactor ID: (629) details collected.
# Reactor ID: (630) details collected.
# Reactor ID: (631) details collected.
# Reactor ID: (632) details collected.
# Reactor ID: (633) details collected.
# Reactor ID: (634) details collected.
# Reactor ID: (635) details collected.
# Reactor ID: (636) details collected.
# Reactor ID: (637) details collected.
# Reactor ID: (638) details collected.
# Reactor ID: (639) details collected.
# Reactor ID: (640) details collected.
# Reactor ID: (641) details collected.
# Reactor ID: (642) details collected.
# Reactor ID: (643) details collected.
# Reactor ID: (644) details collected.
# Reactor ID: (645) details collected.
# Reactor ID: (646) details collected.
# Reactor ID: (647) details collected.
# Reactor ID: (648) details collected.
# Reactor ID: (649) details collected.
# Reactor ID: (650) details collected.
# Reactor ID: (651) details collected.
# Reactor ID: (652) details collected.
# Reactor ID: (653) details collected.
# Reactor ID: (654) details collected.
# Reactor ID: (655) details collected.
# Reactor ID: (656) details collected.
# Reactor ID: (657) details collected.
# Reactor ID: (658) details collected.
# Reactor ID: (659) details collected.
# Reactor ID: (660) details collected.
# Reactor ID: (661) details collected.
# Reactor ID: (662) details collected.
# Reactor ID: (663) details collected.
# Reactor ID: (664) details collected.
# Reactor ID: (665) did not return a valid page.
# Reactor ID: (666) did not return a valid page.
# Reactor ID: (667) details collected.
# Reactor ID: (668) details collected.
# Reactor ID: (669) details collected.
# Reactor ID: (670) details collected.
# Reactor ID: (671) details collected.
# Reactor ID: (672) details collected.
# Reactor ID: (673) details collected.
# Reactor ID: (674) details collected.
# Reactor ID: (675) details collected.
# Reactor ID: (676) details collected.
# Reactor ID: (677) details collected.
# Reactor ID: (678) details collected.
# Reactor ID: (679) details collected.
# Reactor ID: (680) details collected.
# Reactor ID: (681) did not return a valid page.
# Reactor ID: (682) did not return a valid page.
# Reactor ID: (683) details collected.
# Reactor ID: (684) details collected.
# Reactor ID: (685) did not return a valid page.
# Reactor ID: (686) details collected.
# Reactor ID: (687) details collected.
# Reactor ID: (688) did not return a valid page.
# Reactor ID: (689) details collected.
# Reactor ID: (690) details collected.
# Reactor ID: (691) details collected.
# Reactor ID: (692) details collected.
# Reactor ID: (693) details collected.
# Reactor ID: (694) did not return a valid page.
# Reactor ID: (695) details collected.
# Reactor ID: (696) details collected.
# Reactor ID: (697) details collected.
# Reactor ID: (698) details collected.
# Reactor ID: (699) details collected.
# Reactor ID: (700) details collected.
# Reactor ID: (701) details collected.
# Reactor ID: (702) details collected.
# Reactor ID: (703) details collected.
# Reactor ID: (704) details collected.
# Reactor ID: (705) did not return a valid page.
# Reactor ID: (706) did not return a valid page.
# Reactor ID: (707) did not return a valid page.
# Reactor ID: (708) did not return a valid page.
# Reactor ID: (709) did not return a valid page.
# Reactor ID: (710) details collected.
# Reactor ID: (711) details collected.
# Reactor ID: (712) details collected.
# Reactor ID: (713) details collected.
# Reactor ID: (714) details collected.
# Reactor ID: (715) details collected.
# Reactor ID: (716) did not return a valid page.
# Reactor ID: (717) details collected.
# Reactor ID: (718) details collected.
# Reactor ID: (719) details collected.
# Reactor ID: (720) did not return a valid page.
# Reactor ID: (721) did not return a valid page.
# Reactor ID: (722) did not return a valid page.
# Reactor ID: (723) did not return a valid page.
# Reactor ID: (724) did not return a valid page.
# Reactor ID: (725) details collected.
# Reactor ID: (726) did not return a valid page.
# Reactor ID: (727) details collected.
# Reactor ID: (728) did not return a valid page.
# Reactor ID: (729) details collected.
# Reactor ID: (730) details collected.
# Reactor ID: (731) did not return a valid page.
# Reactor ID: (732) did not return a valid page.
# Reactor ID: (733) did not return a valid page.
# Reactor ID: (734) did not return a valid page.
# Reactor ID: (735) details collected.
# Reactor ID: (736) details collected.
# Reactor ID: (737) details collected.
# Reactor ID: (738) details collected.
# Reactor ID: (739) details collected.
# Reactor ID: (740) did not return a valid page.
# Reactor ID: (741) did not return a valid page.
# Reactor ID: (742) details collected.
# Reactor ID: (743) did not return a valid page.
# Reactor ID: (744) did not return a valid page.
# Reactor ID: (745) did not return a valid page.
# Reactor ID: (746) did not return a valid page.
# Reactor ID: (747) did not return a valid page.
# Reactor ID: (748) did not return a valid page.
# Reactor ID: (749) did not return a valid page.
# Reactor ID: (750) did not return a valid page.
# Reactor ID: (751) details collected.
# Reactor ID: (752) details collected.
# Reactor ID: (753) did not return a valid page.
# Reactor ID: (754) did not return a valid page.
# Reactor ID: (755) did not return a valid page.
# Reactor ID: (756) did not return a valid page.
# Reactor ID: (757) did not return a valid page.
# Reactor ID: (758) did not return a valid page.
# Reactor ID: (759) did not return a valid page.
# Reactor ID: (760) did not return a valid page.
# Reactor ID: (761) did not return a valid page.
# Reactor ID: (762) did not return a valid page.
# Reactor ID: (763) did not return a valid page.
# Reactor ID: (764) details collected.
# Reactor ID: (765) details collected.
# Reactor ID: (766) did not return a valid page.
# Reactor ID: (767) did not return a valid page.
# Reactor ID: (768) did not return a valid page.
# Reactor ID: (769) did not return a valid page.
# Reactor ID: (770) did not return a valid page.
# Reactor ID: (771) did not return a valid page.
# Reactor ID: (772) did not return a valid page.
# Reactor ID: (773) did not return a valid page.
# Reactor ID: (774) did not return a valid page.
# Reactor ID: (775) did not return a valid page.
# Reactor ID: (776) did not return a valid page.
# Reactor ID: (777) did not return a valid page.
# Reactor ID: (778) did not return a valid page.
# Reactor ID: (779) did not return a valid page.
# Reactor ID: (780) did not return a valid page.
# Reactor ID: (781) did not return a valid page.
# Reactor ID: (782) did not return a valid page.
# Reactor ID: (783) did not return a valid page.
# Reactor ID: (784) did not return a valid page.
# Reactor ID: (785) did not return a valid page.
# Reactor ID: (786) did not return a valid page.
# Reactor ID: (787) did not return a valid page.
# Reactor ID: (788) did not return a valid page.
# Reactor ID: (789) details collected.
# Reactor ID: (790) details collected.
# Reactor ID: (791) details collected.
# Reactor ID: (792) did not return a valid page.
# Reactor ID: (793) did not return a valid page.
# Reactor ID: (794) did not return a valid page.
# Reactor ID: (795) did not return a valid page.
# Reactor ID: (796) did not return a valid page.
# Reactor ID: (797) did not return a valid page.
# Reactor ID: (798) did not return a valid page.
# Reactor ID: (799) did not return a valid page.
# Reactor ID: (800) did not return a valid page.
# Reactor ID: (801) did not return a valid page.
# Reactor ID: (802) did not return a valid page.
# Reactor ID: (803) did not return a valid page.
# Reactor ID: (804) did not return a valid page.
# Reactor ID: (805) did not return a valid page.
# Reactor ID: (806) did not return a valid page.
# Reactor ID: (807) did not return a valid page.
# Reactor ID: (808) did not return a valid page.
# Reactor ID: (809) did not return a valid page.
# Reactor ID: (810) did not return a valid page.
# Reactor ID: (811) did not return a valid page.
# Reactor ID: (812) did not return a valid page.
# Reactor ID: (813) did not return a valid page.
# Reactor ID: (814) did not return a valid page.
# Reactor ID: (815) did not return a valid page.
# Reactor ID: (816) did not return a valid page.
# Reactor ID: (817) did not return a valid page.
# Reactor ID: (818) did not return a valid page.
# Reactor ID: (819) did not return a valid page.
# Reactor ID: (820) did not return a valid page.
# Reactor ID: (821) did not return a valid page.
# Reactor ID: (822) did not return a valid page.
# Reactor ID: (823) did not return a valid page.
# Reactor ID: (824) did not return a valid page.
# Reactor ID: (825) did not return a valid page.
# Reactor ID: (826) did not return a valid page.
# Reactor ID: (827) did not return a valid page.
# Reactor ID: (828) did not return a valid page.
# Reactor ID: (829) did not return a valid page.
# Reactor ID: (830) did not return a valid page.
# Reactor ID: (831) did not return a valid page.
# Reactor ID: (832) did not return a valid page.
# Reactor ID: (833) did not return a valid page.
# Reactor ID: (834) did not return a valid page.
# Reactor ID: (835) did not return a valid page.
# Reactor ID: (836) details collected.
# Reactor ID: (837) details collected.
# Reactor ID: (838) details collected.
# Reactor ID: (839) details collected.
# Reactor ID: (840) details collected.
# Reactor ID: (841) details collected.
# Reactor ID: (842) details collected.
# Reactor ID: (843) details collected.
# Reactor ID: (844) did not return a valid page.
# Reactor ID: (845) did not return a valid page.
# Reactor ID: (846) did not return a valid page.
# Reactor ID: (847) did not return a valid page.
# Reactor ID: (848) did not return a valid page.
# Reactor ID: (849) did not return a valid page.
# Reactor ID: (850) did not return a valid page.
# Reactor ID: (851) did not return a valid page.
# Reactor ID: (852) details collected.
# Reactor ID: (853) details collected.
# Reactor ID: (854) did not return a valid page.
# Reactor ID: (855) did not return a valid page.
# Reactor ID: (856) details collected.
# Reactor ID: (857) did not return a valid page.
# Reactor ID: (858) did not return a valid page.
# Reactor ID: (859) details collected.
# Reactor ID: (860) details collected.
# Reactor ID: (861) did not return a valid page.
# Reactor ID: (862) details collected.
# Reactor ID: (863) did not return a valid page.
# Reactor ID: (864) details collected.
# Reactor ID: (865) details collected.
# Reactor ID: (866) did not return a valid page.
# Reactor ID: (867) details collected.
# Reactor ID: (868) did not return a valid page.
# Reactor ID: (869) did not return a valid page.
# Reactor ID: (870) did not return a valid page.
# Reactor ID: (871) did not return a valid page.
# Reactor ID: (872) did not return a valid page.
# Reactor ID: (873) details collected.
# Reactor ID: (874) did not return a valid page.
# Reactor ID: (875) details collected.
# Reactor ID: (876) details collected.
# Reactor ID: (877) details collected.
# Reactor ID: (878) details collected.
# Reactor ID: (879) details collected.
# Reactor ID: (880) details collected.
# Reactor ID: (881) details collected.
# Reactor ID: (882) details collected.
# Reactor ID: (883) details collected.
# Reactor ID: (884) details collected.
# Reactor ID: (885) details collected.
# Reactor ID: (886) details collected.
# Reactor ID: (887) details collected.
# Reactor ID: (888) details collected.
# Reactor ID: (889) did not return a valid page.
# Reactor ID: (890) details collected.
# Reactor ID: (891) details collected.
# Reactor ID: (892) details collected.
# Reactor ID: (893) details collected.
# Reactor ID: (894) details collected.
# Reactor ID: (895) details collected.
# Reactor ID: (896) details collected.
# Reactor ID: (897) did not return a valid page.
# Reactor ID: (898) details collected.
# Reactor ID: (899) details collected.
# Reactor ID: (900) details collected.
# Reactor ID: (901) details collected.
# Reactor ID: (902) did not return a valid page.
# Reactor ID: (903) details collected.
# Reactor ID: (904) details collected.
# Reactor ID: (905) details collected.
# Reactor ID: (906) details collected.
# Reactor ID: (907) details collected.
# Reactor ID: (908) details collected.
# Reactor ID: (909) details collected.
# Reactor ID: (910) did not return a valid page.
# Reactor ID: (911) did not return a valid page.
# Reactor ID: (912) details collected.
# Reactor ID: (913) details collected.
# Reactor ID: (914) details collected.
# Reactor ID: (915) details collected.
# Reactor ID: (916) did not return a valid page.
# Reactor ID: (917) did not return a valid page.
# Reactor ID: (918) details collected.
# Reactor ID: (919) details collected.
# Reactor ID: (920) did not return a valid page.
# Reactor ID: (921) details collected.
# Reactor ID: (922) details collected.
# Reactor ID: (923) details collected.
# Reactor ID: (924) details collected.
# Reactor ID: (925) did not return a valid page.
# Reactor ID: (926) did not return a valid page.
# Reactor ID: (927) did not return a valid page.
# Reactor ID: (928) did not return a valid page.
# Reactor ID: (929) did not return a valid page.
# Reactor ID: (930) did not return a valid page.
# Reactor ID: (931) details collected.
# Reactor ID: (932) details collected.
# Reactor ID: (933) details collected.
# Reactor ID: (934) details collected.
# Reactor ID: (935) details collected.
# Reactor ID: (936) details collected.
# Reactor ID: (937) details collected.
# Reactor ID: (938) details collected.
# Reactor ID: (939) details collected.
# Reactor ID: (940) details collected.
# Reactor ID: (941) details collected.
# Reactor ID: (942) did not return a valid page.
# Reactor ID: (943) details collected.
# Reactor ID: (944) details collected.
# Reactor ID: (945) details collected.
# Reactor ID: (946) details collected.
# Reactor ID: (947) did not return a valid page.
# Reactor ID: (948) did not return a valid page.
# Reactor ID: (949) did not return a valid page.
# Reactor ID: (950) did not return a valid page.
# Reactor ID: (951) did not return a valid page.
# Reactor ID: (952) did not return a valid page.
# Reactor ID: (953) did not return a valid page.
# Reactor ID: (954) did not return a valid page.
# Reactor ID: (955) did not return a valid page.
# Reactor ID: (956) did not return a valid page.
# Reactor ID: (957) details collected.
# Reactor ID: (958) did not return a valid page.
# Reactor ID: (959) did not return a valid page.
# Reactor ID: (960) did not return a valid page.
# Reactor ID: (961) did not return a valid page.
# Reactor ID: (962) did not return a valid page.
# Reactor ID: (963) did not return a valid page.
# Reactor ID: (964) did not return a valid page.
# Reactor ID: (965) did not return a valid page.
# Reactor ID: (966) details collected.
# Reactor ID: (967) did not return a valid page.
# Reactor ID: (968) details collected.
# Reactor ID: (969) did not return a valid page.
# Reactor ID: (970) did not return a valid page.
# Reactor ID: (971) did not return a valid page.
# Reactor ID: (972) did not return a valid page.
# Reactor ID: (973) details collected.
# Reactor ID: (974) details collected.
# Reactor ID: (975) details collected.
# Reactor ID: (976) details collected.
# Reactor ID: (977) did not return a valid page.
# Reactor ID: (978) did not return a valid page.
# Reactor ID: (979) did not return a valid page.
# Reactor ID: (980) did not return a valid page.
# Reactor ID: (981) did not return a valid page.
# Reactor ID: (982) did not return a valid page.
# Reactor ID: (983) did not return a valid page.
# Reactor ID: (984) did not return a valid page.
# Reactor ID: (985) did not return a valid page.
# Reactor ID: (986) details collected.
# Reactor ID: (987) details collected.
# Reactor ID: (988) did not return a valid page.
# Reactor ID: (989) did not return a valid page.
# Reactor ID: (990) did not return a valid page.
# Reactor ID: (991) did not return a valid page.
# Reactor ID: (992) did not return a valid page.
# Reactor ID: (993) did not return a valid page.
# Reactor ID: (994) did not return a valid page.
# Reactor ID: (995) did not return a valid page.
# Reactor ID: (996) did not return a valid page.
# Reactor ID: (997) details collected.
# Reactor ID: (998) details collected.
# Reactor ID: (999) did not return a valid page.
# Reactor ID: (1000) did not return a valid page.
# Reactor ID: (1001) did not return a valid page.
# Reactor ID: (1002) did not return a valid page.
# Reactor ID: (1003) did not return a valid page.
# Reactor ID: (1004) did not return a valid page.
# Reactor ID: (1005) did not return a valid page.
# Reactor ID: (1006) did not return a valid page.
# Reactor ID: (1007) did not return a valid page.
# Reactor ID: (1008) details collected.
# Reactor ID: (1009) did not return a valid page.
# Reactor ID: (1010) did not return a valid page.
# Reactor ID: (1011) did not return a valid page.
# Reactor ID: (1012) did not return a valid page.
# Reactor ID: (1013) did not return a valid page.
# Reactor ID: (1014) did not return a valid page.
# Reactor ID: (1015) did not return a valid page.
# Reactor ID: (1016) did not return a valid page.
# Reactor ID: (1017) did not return a valid page.
# Reactor ID: (1018) did not return a valid page.
# Reactor ID: (1019) did not return a valid page.
# Reactor ID: (1020) did not return a valid page.
# Reactor ID: (1021) did not return a valid page.
# Reactor ID: (1022) did not return a valid page.
# Reactor ID: (1023) did not return a valid page.
# Reactor ID: (1024) did not return a valid page.
# Reactor ID: (1025) did not return a valid page.
# Reactor ID: (1026) did not return a valid page.
# Reactor ID: (1027) did not return a valid page.
# Reactor ID: (1028) did not return a valid page.
# Reactor ID: (1029) did not return a valid page.
# Reactor ID: (1030) did not return a valid page.
# Reactor ID: (1031) did not return a valid page.
# Reactor ID: (1032) did not return a valid page.
# Reactor ID: (1033) did not return a valid page.
# Reactor ID: (1034) did not return a valid page.
# Reactor ID: (1035) did not return a valid page.
# Reactor ID: (1036) did not return a valid page.
# Reactor ID: (1037) did not return a valid page.
# Reactor ID: (1038) did not return a valid page.
# Reactor ID: (1039) did not return a valid page.
# Reactor ID: (1040) did not return a valid page.
# Reactor ID: (1041) did not return a valid page.
# Reactor ID: (1042) details collected.
# Reactor ID: (1043) details collected.
# Reactor ID: (1044) details collected.
# Reactor ID: (1045) details collected.
# Reactor ID: (1046) did not return a valid page.
# Reactor ID: (1047) details collected.
# Reactor ID: (1048) did not return a valid page.
# Reactor ID: (1049) did not return a valid page.
# Reactor ID: (1050) details collected.
# Reactor ID: (1051) details collected.
# Reactor ID: (1052) details collected.
# Reactor ID: (1053) details collected.
# Reactor ID: (1054) did not return a valid page.
# Reactor ID: (1055) details collected.
# Reactor ID: (1056) details collected.
# Reactor ID: (1057) did not return a valid page.
# Reactor ID: (1058) did not return a valid page.
# Reactor ID: (1059) details collected.
# Reactor ID: (1060) details collected.
# Reactor ID: (1061) details collected.
# Reactor ID: (1062) did not return a valid page.
# Reactor ID: (1063) did not return a valid page.
# Reactor ID: (1064) did not return a valid page.
# Reactor ID: (1065) did not return a valid page.
# Reactor ID: (1066) did not return a valid page.
# Reactor ID: (1067) details collected.
# Reactor ID: (1068) details collected.
# Reactor ID: (1069) did not return a valid page.
# Reactor ID: (1070) did not return a valid page.
# Reactor ID: (1071) did not return a valid page.
# Reactor ID: (1072) details collected.
# Reactor ID: (1073) details collected.
# Reactor ID: (1074) details collected.
# Reactor ID: (1075) details collected.
# Reactor ID: (1076) did not return a valid page.
# Reactor ID: (1077) did not return a valid page.
# Reactor ID: (1078) details collected.
# Reactor ID: (1079) details collected.
# Reactor ID: (1080) details collected.
# Reactor ID: (1081) details collected.
# Reactor ID: (1082) did not return a valid page.
# Reactor ID: (1083) details collected.
# Reactor ID: (1084) details collected.
# Reactor ID: (1085) did not return a valid page.
# Reactor ID: (1086) did not return a valid page.
# Reactor ID: (1087) did not return a valid page.
# Reactor ID: (1088) did not return a valid page.
# Reactor ID: (1089) did not return a valid page.
# Reactor ID: (1090) details collected.
# Reactor ID: (1091) details collected.
# Reactor ID: (1092) did not return a valid page.
# Reactor ID: (1093) did not return a valid page.
# Reactor ID: (1094) details collected.
# Reactor ID: (1095) did not return a valid page.
# Reactor ID: (1096) did not return a valid page.
# Reactor ID: (1097) did not return a valid page.
# Reactor ID: (1098) did not return a valid page.
# Reactor ID: (1099) did not return a valid page.
# Reactor ID: (1100) did not return a valid page.
# Reactor ID: (1101) details collected.
# Reactor ID: (1102) did not return a valid page.
# Reactor ID: (1103) did not return a valid page.
# Reactor ID: (1104) did not return a valid page.
# Reactor ID: (1105) did not return a valid page.
# Reactor ID: (1106) did not return a valid page.
# Reactor ID: (1107) did not return a valid page.
# Reactor ID: (1108) did not return a valid page.
# Reactor ID: (1109) did not return a valid page.
# Reactor ID: (1110) did not return a valid page.
# Reactor ID: (1111) did not return a valid page.
# Reactor ID: (1112) did not return a valid page.
# Reactor ID: (1113) did not return a valid page.
# Reactor ID: (1114) did not return a valid page.
# Reactor ID: (1115) did not return a valid page.
# Reactor ID: (1116) did not return a valid page.
# Reactor ID: (1117) did not return a valid page.
# Reactor ID: (1118) did not return a valid page.
# Reactor ID: (1119) did not return a valid page.
# Reactor ID: (1120) did not return a valid page.
# Reactor ID: (1121) did not return a valid page.
# Reactor ID: (1122) did not return a valid page.
# Reactor ID: (1123) did not return a valid page.
# Reactor ID: (1124) did not return a valid page.
# Reactor ID: (1125) did not return a valid page.
# Reactor ID: (1126) did not return a valid page.
# Reactor ID: (1127) did not return a valid page.
# Reactor ID: (1128) did not return a valid page.
# Reactor ID: (1129) did not return a valid page.
# Reactor ID: (1130) did not return a valid page.
# Reactor ID: (1131) did not return a valid page.
# Reactor ID: (1132) did not return a valid page.
# Reactor ID: (1133) did not return a valid page.
# Reactor ID: (1134) did not return a valid page.
# Reactor ID: (1135) did not return a valid page.
# Reactor ID: (1136) did not return a valid page.
# Reactor ID: (1137) did not return a valid page.
# Reactor ID: (1138) did not return a valid page.
# Reactor ID: (1139) did not return a valid page.
# Reactor ID: (1140) did not return a valid page.
# Reactor ID: (1141) did not return a valid page.
# Reactor ID: (1142) did not return a valid page.
# Reactor ID: (1143) did not return a valid page.
# Reactor ID: (1144) did not return a valid page.
# Reactor ID: (1145) did not return a valid page.
# Reactor ID: (1146) did not return a valid page.
# Reactor ID: (1147) did not return a valid page.
# Reactor ID: (1148) did not return a valid page.
# Reactor ID: (1149) did not return a valid page.

# %% [markdown]
# #### Creating dataframes from our collected lists

# %%
reactor_details_df = pd.DataFrame(reactor_details_list, columns=[
	"reactor_Type", 
	'model', 
	'design_net_capacity', 
	'construction_start_date', 
	"commercial_operation_date", 
	"owner", 
	"operator", 
	"Shutdown Date",
	"country", 
	"reactor_name"])

main_tables_df = pd.DataFrame(main_tables_list, columns = [
	"Year", 
	"Electricity Supplied [GW.h]", 
	"Reference Unit Power [MW]", 
	"Annual Time On Line [h]", 
	"Operation Factor [%]", 
	"Annual Energy Availability Factor [%]", 
	"Cumulative Energy Availability Factor [%]", 
	"Annual Load Factor [%]", 
	"Cumulative Load Factor [%]", 
	"country", 
	"reactor_name"])

# %% [markdown]
# ### Data cleanup

# %%
#Clean up string values, empty values and NaN in all columns that should have only numerical data
for col in main_tables_df.columns:
    if "[" in col:
        main_tables_df[col] = (pd.to_numeric(main_tables_df[col],errors='coerce').fillna(0))

for col in reactor_details_df.columns:
    reactor_details_df[col] = reactor_details_df[col].fillna(0)

#Keep only numeric values for capacity
reactor_details_df["design_net_capacity"] = reactor_details_df.design_net_capacity.str.extract('(\d+)')

# %% [markdown]
# ### Adding columns

# %%
# Adding reactur status based on available commercial operation date, or shutdown date
reactor_details_df["Status"] = np.where(reactor_details_df["Shutdown Date"]!= 0, "Permanent shutdown",
                            np.where(reactor_details_df["commercial_operation_date"]== 0, "Under Construction", "Operational"))
main_tables_df["Calendar_Date"] = pd.to_datetime(dict(year=main_tables_df['Year'], month=1, day=1)).dt.date

# %% [markdown]
# #### Saving dataframes to .csv files for further use. Available in git repo.

# %%
main_tables_df.to_csv(path_or_buf = "main_tables_output.csv", index=False)
reactor_details_df.to_csv(path_or_buf = "reactor_details_output.csv", index=False)

#load df from csv files if necessary
#main_tables_df = pd.read_csv("main_tables_output.csv", sep=';')
#reactor_details_df = pd.read_csv("reactor_details_output.csv", sep=';')

# %% [markdown]
# #### Minor formating was performed in Excel, then the data was imported to Tableau.
#
# Country names edited manually to confirm to ISO 3166

# %%
#'Need to redo the event file'
# Out:
#   File "C:\Users\letso\AppData\Local\Temp/ipykernel_22912/2940017774.py", line 1
#     reactor_details_df.head(23;23)
#                               ^
# SyntaxError: invalid syntax
